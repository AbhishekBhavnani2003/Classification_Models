# %% [markdown]
# ### Question 1.
#  Create a program that stores your name and age in variables and prints them in a sentence.

# %% [markdown]
# ### Question 2.
# Convert the following values using casting:
#
# a. Convert "25" to integer
#
# b. Convert 7 to float
#
# c. Convert 3.14 to string

# %% [markdown]
# ### Question 3.
# Identify which variable names are valid or invalid according to Python naming rules:
#
# | Variable Name | Valid / Invalid |
# | ------------- | --------------- |
# | `myVar`       | ?               |
# | `2value`      | ?               |
# | `_roll_no`    | ?               |
# | `class`       | ?               |
# | `total_value` | ?               |

# %% [markdown]
# ### Question 4.
# Write a program that demonstrates global and local variables.

# %% [markdown]
# ### Question 5.
# Modify a global variable inside a function using the global keyword.
