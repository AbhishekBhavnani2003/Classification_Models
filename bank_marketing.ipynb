# %% [markdown]
# # Problem Statement
#
# A bank conducted marketing campaigns to promote term deposit subscriptions.
# Based on customer demographic and campaign information, build a machine learning model to predict whether a customer will subscribe to a term deposit.

# %% [markdown]
# ### Dataset Link
#
# https://www.kaggle.com/datasets/adityamhaske/bank-marketing-dataset
